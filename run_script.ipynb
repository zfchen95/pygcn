# %%
# !bash train.sh
# Out:
# Loading 2018-06-10 dataset...
# number of nodes in training set:  7130
# Optimization Finished!
# Total time elapsed: 6.4175s
# Loading 2018-06-10 dataset...
# number of nodes in test set:  7130
# Loading 2018-06-11 dataset...
# number of nodes in training set:  11058
# Optimization Finished!
# Total time elapsed: 6.7164s
# Loading 2018-06-10 dataset...
# number of nodes in test set:  7130
# Loading 2018-06-12 dataset...
# number of nodes in training set:  10966
# Optimization Finished!
# Total time elapsed: 6.3341s
# Loading 2018-06-10 dataset...
# number of nodes in test set:  7130
# Loading 2018-06-13 dataset...
# number of nodes in training set:  11967
# Optimization Finished!
# Total time elapsed: 7.1243s
# Loading 2018-06-10 dataset...
# number of nodes in test set:  7130
# Loading 2018-06-14 dataset...
# number of nodes in training set:  11542
# Optimization Finished!
# Total time elapsed: 6.7070s
# Loading 2018-06-10 dataset...
# number of nodes in test set:  7130
# ...
